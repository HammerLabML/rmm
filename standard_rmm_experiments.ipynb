# %% [markdown]
# ## Standard RMM experiments
#
# This notebook accumulates experiments for all benchmark datasets that can be handled with standard reservoir memory machines, in particular the latch, copy, repeat copy, and signal copy task. FSM learning and associative recall require some special concepts and are handled in separate notebooks.

# %%
# in this first cell we set some experimental meta-parameters that are used across all
# datasets

# the number of training time series
N = 90
# the number of test time series
N_test = 10
# the number of repeats for the experiments
R = 20
# the names of the tasks to be performed
tasks = ['latch', 'copy', 'repeat_copy', 'signal_copy']
# the number of neurons for each task
num_neurons = [64, 256, 256, 64]
# the number of input dimensions for each task
ns = [1, 9, 9, 2]
# the SVM kernel to be used (which is different for each task)
svm_kernels = ['rbf', 'linear', 'linear', 'pseudo']

# %% [markdown]
# ## Hyperparameter Optimization

# %%
# the number of hyperparameter combinations to be tested
hyper_R = 10
# the number of repeats for each hyperparameter combination
hyper_num_repeats = 3
# set the hyper-parameter ranges for all models
models = ['ESN', 'CRJ', 'LMU', 'RMM_ESN', 'RMM_CRJ', 'RMM_LMU']
hyperparam_ranges = {
    'ESN' : {
        'radius' : [0.5, 0.7, 0.9],
        'sparsity' : [0.1, 0.2, 0.5],
        'regul' : [1E-7, 1E-5, 1E-3]
    },
    'CRJ' : {
        'v' : [0.1, 0.3, 0.5],
        'w_c' : [0.1, 0.7, 0.9],
        'w_j' : [0.1, 0.2, 0.4],
        'l' : [4, 8, 16],
        'regul' : [1E-7, 1E-5, 1E-3]
    },
    'LMU' : {
        'regul' : [1E-7, 1E-5, 1E-3],
        'T' : [16, 32, 128, 384]
    },
    'RMM_ESN' : {
        'radius' : [0.5, 0.7, 0.9],
        'sparsity' : [0.1, 0.2, 0.5],
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.]
    },
    'RMM_CRJ' : {
        'v' : [0.1, 0.3, 0.5],
        'w_c' : [0.1, 0.7, 0.9],
        'w_j' : [0.1, 0.2, 0.4],
        'l' : [4, 8, 16],
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.]
    },
    'RMM_LMU' : {
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.],
        'T' : [16, 32, 128, 384]
    }
}

import numpy as np
import esn
import crj
import lmu
import rmm

# set up a function to initialize an instance for each model
def setup_model(model, m, n, hyperparams):
    # first, set up the correct reservoir and nonlinearity
    if model.endswith('ESN'):
        U, W = esn.initialize_reservoir(m, n, radius = hyperparams['radius'],
                                        sparsity = hyperparams['sparsity'])
        nonlin = np.tanh
    elif model.endswith('CRJ'):
        U = crj.setup_input_weight_matrix(n, m, v = hyperparams['v'])
        W = crj.setup_reservoir_matrix(m, w_c = hyperparams['w_c'],
                                       w_j = hyperparams['w_j'], l = hyperparams['l'])
        nonlin = np.tanh
    elif model.endswith('LMU'):
        degree = int(m/n)-1
        U, W = lmu.initialize_reservoir(n, degree, hyperparams['T'])
        nonlin = lambda x : x
    else:
        raise ValueError('Unknown model: %s' % model)
    # then, set up the model
    if not model.startswith('RMM_'):
        net = esn.ESN(U, W, regul = hyperparams['regul'], input_normalization = False,
                      nonlin = nonlin)
    else:
        net = rmm.RMM(U, W, regul = hyperparams['regul'], input_normalization = False,
                      nonlin = nonlin, C = hyperparams['C'],
                      svm_kernel = hyperparams['svm_kernel'])
    return net

# %% [markdown]
# ## Experiment
#
# After all the hyperparameter setup above we can now iterate over all tasks and
# first perform hyperparameter optimization, followed by the actual experiment.

# %%
import json
import os
import random
import time
from dataset_generators import generate_data
from dataset_generators import _permutation_sampling

# iterate over all tasks
for task_idx in range(3, len(tasks)):
    task = tasks[task_idx]
    print('------ Task %d of %d: %s -----' % (task_idx+1, len(tasks), task))
    m = num_neurons[task_idx]
    n = ns[task_idx]
    svm_kernel = svm_kernels[task_idx]
    # try to load the selected hyperparameters from file
    hyperparam_path = '%s_hyperparams.json' % task
    if os.path.isfile(hyperparam_path):
        print('loading hyperparameters from %s' % hyperparam_path)
        with open(hyperparam_path, 'r') as hyperparam_file:
            hyperparams = json.load(hyperparam_file)
    else:
        # perform a hyperoptimization where we test R random hyperparameter
        # settings for each model and perform num_repeats repeats to obtain
        # statistics. The hyperparameters with the best mean performance across
        # repeats will be selected
        print('performing hyperparameter optimization (this may take a while)')
        # generate random parameter combination for all models
        hyperparams = {}
        for model in models:
            # initialize a hyperparameter dictionary for each combination
            hyperparams[model] = []
            for r in range(hyper_R):
                hyperparams[model].append({})
            # then iterate over each key and sample the parameter values
            for key in hyperparam_ranges[model]:
                param_range = hyperparam_ranges[model][key]
                param_value_indices = _permutation_sampling(hyper_R, 0, len(param_range)-1)
                for r in range(hyper_R):
                    value = param_range[param_value_indices[r]]
                    hyperparams[model][r][key] = value
            for r in range(hyper_R):
                # set up an extra key for the errors
                hyperparams[model][r]['errors'] = []
                # and set the SVM kernel for RMM models
                if model.startswith('RMM_'):
                    hyperparams[model][r]['svm_kernel'] = svm_kernel

        for repeat in range(hyper_num_repeats):
            print('--- repeat %d of %d ---' % (repeat+1, hyper_num_repeats))
            # sample training and test data
            Xs, Qs, Ys = generate_data(N, task)
            Xs_test, Qs_test, Ys_test = generate_data(N_test, task)
            # now iterate over all models
            for model in models:
                print('-- model: %s --' % model)
                # and iterate over all parameter combinations for this model
                for params_r in hyperparams[model]:
                    # set up a model instance
                    net = setup_model(model, m, n, params_r)
                    # fit the model to the data
                    if model.startswith('RMM_'):
                        net.fit(Xs, Qs, Ys)
                    else:
                        net.fit(Xs, Ys)
                    # measure the RMSE on the test data
                    mse = 0.
                    for i in range(N_test):
                        Ypred = net.predict(Xs_test[i])
                        mse   += np.mean((Ypred - Ys_test[i]) ** 2)
                    rmse = np.sqrt(mse / N_test)
                    params_r['errors'].append(rmse)
                    print('error: %g' % rmse)
        # write the results to a JSON file
        with open(hyperparam_path, 'w') as hyperparam_file:
            json.dump(hyperparams, hyperparam_file)

    # select best hyperparameters for each model
    hyperparams_opt = {}
    for model in models:
        min_err = np.inf
        for params_r in hyperparams[model]:
            if np.mean(params_r['errors']) < min_err:
                min_err = np.mean(params_r['errors'])
                hyperparams_opt[model] = params_r
        print('\nSelected the following hyper-parameters for %s' % model)
        for key in hyperparams_opt[model]:
            print('%s: %s' % (key, str(hyperparams_opt[model][key])))
    # hyperparameter optimization complete
    
    # ACTUAL EXPERIMENT

    # initialize error and runtime arrays
    errors   = np.zeros((len(models), R))
    runtimes = np.zeros((len(models), R))
    # iterate over all experimental repeats
    for r in range(R):
        print('--- repeat %d of %d ---' % (r+1, R))
        # sample training and test data
        Xs, Qs, Ys = generate_data(N, task)
        Xs_test, Qs_test, Ys_test = generate_data(N_test, task)
        # now iterate over all models
        for model_idx in range(len(models)):
            model = models[model_idx]
            # print('-- model: %s --' % model)
            # set up the model with the best selected hyperparameters
            start_time = time.time()
            net = setup_model(model, m, n, hyperparams_opt[model])
            # fit the model to the data
            if model.startswith('RMM_'):
                net.fit(Xs, Qs, Ys)
            else:
                net.fit(Xs, Ys)
            # measure the RMSE on the test data
            mse = 0.
            for i in range(N_test):
                Ypred = net.predict(Xs_test[i])
                mse   += np.mean((Ypred - Ys_test[i]) ** 2)
            rmse = np.sqrt(mse / N_test)
            runtimes[model_idx, r] = time.time() - start_time
            errors[model_idx, r] = rmse
    # print results
    for model_idx in range(len(models)):
        print('%s: %g +- %g (took %g seconds)' % (models[model_idx], np.mean(errors[model_idx, :]), np.std(errors[model_idx, :]), np.mean(runtimes[model_idx, :])))
    # write results to file
    np.savetxt('%s_errors.csv' % task, errors.T, delimiter='\t', header='\t'.join(models), comments='')
    np.savetxt('%s_runtimes.csv' % task, runtimes.T, delimiter='\t', header='\t'.join(models), comments='')
# Out:
# ------ Task 4 of 4: signal_copy -----
# performing hyperparameter optimization (this may take a while)
# --- repeat 1 of 3 ---
# -- model: ESN --
# error: 2.58433
# error: 2.58588
# error: 2.58687
# error: 2.58661
# error: 2.58608
# error: 2.58621
# error: 2.58778
# error: 2.58552
# error: 2.58832
# error: 2.58629
# -- model: CRJ --
# error: 2.5814
# error: 2.5868
# error: 2.59518
# error: 2.58277
# error: 2.57988
# error: 2.58206
# error: 2.58362
# error: 2.58018
# error: 2.58638
# error: 2.58117
# -- model: LMU --
# error: 2.55803
# error: 2.57131
# error: 2.57756
# error: 2.29008
# error: 2.57756
# error: 2.29011
# error: 2.55802
# error: 2.57131
# error: 2.29011
# error: 2.57737
# -- model: RMM_ESN --
# State prediction recall: 0.973333; precision: 0.973333
# error: 2.58375
# State prediction recall: 0.951111; precision: 0.951111
# error: 2.58561
# State prediction recall: 0.98963; precision: 0.975182
# error: 2.58704
# State prediction recall: 0.977778; precision: 0.982143
# error: 2.58639
# State prediction recall: 0.974815; precision: 0.987988
# error: 2.58603
# State prediction recall: 0.957037; precision: 0.958457
# error: 2.58684
# State prediction recall: 0.968889; precision: 0.974665
# error: 2.58391
# State prediction recall: 0.967407; precision: 0.957478
# error: 2.58702
# State prediction recall: 0.922963; precision: 0.954058
# error: 2.5873
# State prediction recall: 0.980741; precision: 0.977843
# error: 2.58335
# -- model: RMM_CRJ --
# State prediction recall: 0.96; precision: 0.981818
# error: 2.58606
# State prediction recall: 0.979259; precision: 0.982169
# error: 2.57892
# State prediction recall: 0.976296; precision: 0.976296
# error: 2.59884
# State prediction recall: 0.964444; precision: 0.973094
# error: 2.58639
# State prediction recall: 0.976296; precision: 0.976296
# error: 2.57881
# State prediction recall: 0.980741; precision: 0.983655
# error: 2.57928
# State prediction recall: 0.965926; precision: 0.973134
# error: 2.57863
# State prediction recall: 0.983704; precision: 0.985163
# error: 2.58309
# State prediction recall: 0.958519; precision: 0.97882
# error: 2.58018
# State prediction recall: 0.854815; precision: 0.854815
# error: 2.59505
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 2.57721
# State prediction recall: 1; precision: 1
# error: 0.0591145
# State prediction recall: 1; precision: 1
# error: 2.48285
# State prediction recall: 1; precision: 1
# error: 2.57129
# State prediction recall: 1; precision: 1
# error: 2.5716
# State prediction recall: 1; precision: 1
# error: 0.0591148
# State prediction recall: 1; precision: 1
# error: 2.48223
# State prediction recall: 1; precision: 1
# error: 2.57741
# State prediction recall: 1; precision: 1
# error: 2.57129
# State prediction recall: 1; precision: 1
# error: 2.48223
# --- repeat 2 of 3 ---
# -- model: ESN --
# error: 2.66071
# error: 2.66265
# error: 2.66155
# error: 2.65581
# error: 2.66289
# error: 2.66632
# error: 2.66022
# error: 2.6614
# error: 2.66464
# error: 2.66114
# -- model: CRJ --
# error: 2.64611
# error: 2.6675
# error: 2.67653
# error: 2.66755
# error: 2.65605
# error: 2.6548
# error: 2.66041
# error: 2.65192
# error: 2.66328
# error: 2.64789
# -- model: LMU --
# error: 2.64394
# error: 2.64484
# error: 2.64575
# error: 2.29235
# error: 2.64575
# error: 2.29235
# error: 2.64393
# error: 2.64484
# error: 2.29235
# error: 2.64578
# -- model: RMM_ESN --
# State prediction recall: 0.97037; precision: 0.977612
# error: 2.66575
# State prediction recall: 0.971852; precision: 0.977645
# error: 2.66064
# State prediction recall: 0.991111; precision: 0.980938
# error: 2.657
# State prediction recall: 0.985185; precision: 0.985185
# error: 2.66696
# State prediction recall: 0.983704; precision: 0.982249
# error: 2.65728
# State prediction recall: 0.973333; precision: 0.976226
# error: 2.6613
# State prediction recall: 0.942222; precision: 0.935294
# error: 2.66659
# State prediction recall: 0.983704; precision: 0.977909
# error: 2.66148
# State prediction recall: 0.946667; precision: 0.962349
# error: 2.66249
# State prediction recall: 0.980741; precision: 0.991018
# error: 2.6609
# -- model: RMM_CRJ --
# State prediction recall: 0.97037; precision: 0.99393
# error: 2.66416
# State prediction recall: 0.986667; precision: 0.988131
# error: 2.64787
# State prediction recall: 0.979259; precision: 0.980712
# error: 2.69951
# State prediction recall: 0.965926; precision: 0.977511
# error: 2.66592
# State prediction recall: 0.97037; precision: 0.982009
# error: 2.65009
# State prediction recall: 0.983704; precision: 0.985163
# error: 2.6484
# State prediction recall: 0.961481; precision: 0.968657
# error: 2.65126
# State prediction recall: 0.988148; precision: 0.995522
# error: 2.65081
# State prediction recall: 0.952593; precision: 0.977204
# error: 2.65866
# State prediction recall: 0.819259; precision: 0.819259
# error: 2.6598
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 2.64758
# State prediction recall: 1; precision: 1
# error: 0.0543787
# State prediction recall: 1; precision: 1
# error: 2.61129
# State prediction recall: 1; precision: 1
# error: 2.64541
# State prediction recall: 1; precision: 1
# error: 2.64604
# State prediction recall: 1; precision: 1
# error: 0.0543775
# State prediction recall: 1; precision: 1
# error: 2.61002
# State prediction recall: 1; precision: 1
# error: 2.64754
# State prediction recall: 1; precision: 1
# error: 2.64541
# State prediction recall: 1; precision: 1
# error: 2.61002
# --- repeat 3 of 3 ---
# -- model: ESN --
# error: 1.2516
# error: 1.25129
# error: 1.25168
# error: 1.25164
# error: 1.25077
# error: 1.25138
# error: 1.25109
# error: 1.25138
# error: 1.25147
# error: 1.25172
# -- model: CRJ --
# error: 1.25014
# error: 1.25194
# error: 1.2595
# error: 1.2517
# error: 1.24477
# error: 1.25184
# error: 1.25248
# error: 1.25138
# error: 1.25155
# error: 1.25128
# -- model: LMU --
# error: 1.24976
# error: 1.23961
# error: 1.24843
# error: 1.11392
# error: 1.24843
# error: 1.11391
# error: 1.24975
# error: 1.23961
# error: 1.11391
# error: 1.24827
# -- model: RMM_ESN --
# State prediction recall: 0.967407; precision: 0.950509
# error: 1.25147
# State prediction recall: 0.951111; precision: 0.971256
# error: 1.25141
# State prediction recall: 0.98963; precision: 0.973761
# error: 1.25155
# State prediction recall: 0.985185; precision: 0.985185
# error: 1.2514
# State prediction recall: 0.986667; precision: 0.992548
# error: 1.25179
# State prediction recall: 0.98963; precision: 0.988166
# error: 1.25278
# State prediction recall: 0.976296; precision: 0.971976
# error: 1.25141
# State prediction recall: 0.986667; precision: 0.985207
# error: 1.2516
# State prediction recall: 0.985185; precision: 0.991058
# error: 1.25134
# State prediction recall: 0.973333; precision: 0.971893
# error: 1.24979
# -- model: RMM_CRJ --
# State prediction recall: 0.967407; precision: 0.987897
# error: 1.25208
# State prediction recall: 0.995556; precision: 0.998514
# error: 1.25154
# State prediction recall: 0.971852; precision: 0.971852
# error: 1.28397
# State prediction recall: 0.967407; precision: 0.965976
# error: 1.25314
# State prediction recall: 0.982222; precision: 0.98368
# error: 1.25118
# State prediction recall: 0.98963; precision: 0.994048
# error: 1.2516
# State prediction recall: 0.96; precision: 0.97006
# error: 1.25133
# State prediction recall: 0.986667; precision: 0.982301
# error: 1.25017
# State prediction recall: 0.96; precision: 0.97006
# error: 1.25183
# State prediction recall: 0.856296; precision: 0.856296
# error: 1.29264
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 1.24845
# State prediction recall: 1; precision: 1
# error: 0.0343014
# State prediction recall: 1; precision: 1
# error: 1.31064
# State prediction recall: 1; precision: 1
# error: 1.24172
# State prediction recall: 1; precision: 1
# error: 1.2418
# State prediction recall: 1; precision: 1
# error: 0.0342992
# State prediction recall: 1; precision: 1
# error: 1.3097
# State prediction recall: 1; precision: 1
# error: 1.24862
# State prediction recall: 1; precision: 1
# error: 1.24172
# State prediction recall: 1; precision: 1
# error: 1.3097
#
# Selected the following hyper-parameters for ESN
# radius: 0.5
# sparsity: 0.2
# regul: 1e-05
# errors: [2.58660900937215, 2.655806703399529, 1.2516381634477924]
#
# Selected the following hyper-parameters for CRJ
# v: 0.1
# w_c: 0.1
# w_j: 0.1
# l: 16
# regul: 0.001
# errors: [2.5813957450362075, 2.6461104295070537, 1.2501445973386185]
#
# Selected the following hyper-parameters for LMU
# regul: 0.001
# T: 384
# errors: [2.2900826043966505, 2.292348353324163, 1.1139172516855211]
#
# Selected the following hyper-parameters for RMM_ESN
# radius: 0.9
# sparsity: 0.1
# regul: 1e-07
# C: 100.0
# errors: [2.5833529729180023, 2.660901982474069, 1.2497942639318813]
# svm_kernel: pseudo
#
# Selected the following hyper-parameters for RMM_CRJ
# v: 0.3
# w_c: 0.1
# w_j: 0.2
# l: 16
# regul: 0.001
# C: 10000.0
# errors: [2.578918435130167, 2.6478711467974647, 1.2515403981381823]
# svm_kernel: pseudo
#
# Selected the following hyper-parameters for RMM_LMU
# regul: 1e-05
# C: 10000.0
# T: 384
# errors: [0.059114756942060386, 0.05437746016945756, 0.03429924516652071]
# svm_kernel: pseudo
# --- repeat 1 of 20 ---
# State prediction recall: 0.967407; precision: 0.992401
# State prediction recall: 0.533333; precision: 0.536513
# State prediction recall: 1; precision: 1
# --- repeat 2 of 20 ---
# State prediction recall: 0.979259; precision: 0.970631
# State prediction recall: 0.982222; precision: 0.98368
# State prediction recall: 1; precision: 1
# --- repeat 3 of 20 ---
# State prediction recall: 0.976296; precision: 0.976296
# State prediction recall: 0.982222; precision: 0.985141
# State prediction recall: 1; precision: 1
# --- repeat 4 of 20 ---
# State prediction recall: 0.971852; precision: 0.984985
# State prediction recall: 0.971852; precision: 0.973294
# State prediction recall: 1; precision: 1
# --- repeat 5 of 20 ---
# State prediction recall: 0.928889; precision: 0.942857
# State prediction recall: 0.986667; precision: 0.992548
# State prediction recall: 1; precision: 1
# --- repeat 6 of 20 ---
# State prediction recall: 0.979259; precision: 0.976366
# State prediction recall: 0.940741; precision: 0.943536
# State prediction recall: 1; precision: 1
# --- repeat 7 of 20 ---
# State prediction recall: 0.974815; precision: 0.979167
# State prediction recall: 0.52; precision: 0.5231
# State prediction recall: 1; precision: 1
# --- repeat 8 of 20 ---
# State prediction recall: 0.973333; precision: 0.979136
# State prediction recall: 0.974815; precision: 0.977712
# State prediction recall: 1; precision: 1
# --- repeat 9 of 20 ---
# State prediction recall: 0.982222; precision: 0.98368
# State prediction recall: 0.983704; precision: 0.991045
# State prediction recall: 1; precision: 1
# --- repeat 10 of 20 ---
# State prediction recall: 0.98963; precision: 0.986706
# State prediction recall: 0.98963; precision: 0.991098
# State prediction recall: 1; precision: 1
# --- repeat 11 of 20 ---
# State prediction recall: 0.980741; precision: 0.985119
# State prediction recall: 0.986667; precision: 0.991071
# State prediction recall: 1; precision: 1
# --- repeat 12 of 20 ---
# State prediction recall: 0.986667; precision: 0.989599
# State prediction recall: 0.985185; precision: 0.989583
# State prediction recall: 1; precision: 1
# --- repeat 13 of 20 ---
# State prediction recall: 0.962963; precision: 0.980392
# State prediction recall: 0.542222; precision: 0.544643
# State prediction recall: 1; precision: 1
# --- repeat 14 of 20 ---
# State prediction recall: 0.979259; precision: 0.967789
# State prediction recall: 0.991111; precision: 0.994056
# State prediction recall: 1; precision: 1
# --- repeat 15 of 20 ---
# State prediction recall: 0.980741; precision: 0.989537
# State prediction recall: 0.980741; precision: 0.986587
# State prediction recall: 1; precision: 1
# --- repeat 16 of 20 ---
# State prediction recall: 0.973333; precision: 0.956332
# State prediction recall: 0.98963; precision: 0.995529
# State prediction recall: 1; precision: 1
# --- repeat 17 of 20 ---
# State prediction recall: 0.957037; precision: 0.959881
# State prediction recall: 0.979259; precision: 0.980712
# State prediction recall: 1; precision: 1
# --- repeat 18 of 20 ---
# State prediction recall: 0.952593; precision: 0.956845
# State prediction recall: 0.988148; precision: 0.994039
# State prediction recall: 1; precision: 1
# --- repeat 19 of 20 ---
# State prediction recall: 0.982222; precision: 0.977876
# State prediction recall: 0.992593; precision: 0.997024
# State prediction recall: 1; precision: 1
# --- repeat 20 of 20 ---
# State prediction recall: 0.991111; precision: 0.976642
# State prediction recall: 0.992593; precision: 0.994065
# State prediction recall: 0.998519; precision: 0.998519
# ESN: 18.1688 +- 43.8686 (took 3.65885 seconds)
# CRJ: 17.7891 +- 43.9286 (took 3.45766 seconds)
# LMU: 16.0407 +- 38.2713 (took 3.83778 seconds)
# RMM_ESN: 18.1342 +- 43.8714 (took 5.26716 seconds)
# RMM_CRJ: 17.7619 +- 43.9344 (took 5.02418 seconds)
# RMM_LMU: 5.40713 +- 21.4959 (took 5.38134 seconds)
