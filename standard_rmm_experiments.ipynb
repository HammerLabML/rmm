# %% [markdown]
# ## Standard RMM experiments
#
# This notebook accumulates experiments for all benchmark datasets that can be handled with standard reservoir memory machines, in particular the latch, copy, repeat copy, and signal copy task. FSM learning and associative recall require some special concepts and are handled in separate notebooks.

# %%
# in this first cell we set some experimental meta-parameters that are used across all
# datasets

# the number of training time series
N = 90
# the number of test time series
N_test = 10
# the number of repeats for the experiments
R = 20
# the names of the tasks to be performed
tasks = ['latch', 'copy', 'repeat_copy', 'signal_copy']
# the number of neurons for each task
num_neurons = [64, 256, 256, 64]
# the number of input dimensions for each task
ns = [1, 9, 9, 2]
# the horizons for each task
Ts = [256, 24, 16, 312]

# %% [markdown]
# ## Hyperparameter Optimization

# %%
# the number of hyperparameter combinations to be tested
hyper_R = 20
# the number of repeats for each hyperparameter combination
hyper_num_repeats = 3
# set the hyper-parameter ranges for all models
models = ['ESN', 'CRJ', 'LMU', 'RMM_ESN', 'RMM_CRJ', 'RMM_LMU']
hyperparam_ranges = {
    'ESN' : {
        'radius' : [0.5, 0.7, 0.9],
        'sparsity' : [0.1, 0.2, 0.5],
        'regul' : [1E-7, 1E-5, 1E-3]
    },
    'CRJ' : {
        'v' : [0.1, 0.3, 0.5],
        'w_c' : [0.1, 0.7, 0.9],
        'w_j' : [0.1, 0.2, 0.4],
        'l' : [4, 8, 16],
        'regul' : [1E-7, 1E-5, 1E-3]
    },
    'LMU' : {
        'regul' : [1E-7, 1E-5, 1E-3],
        #'T' : [16, 32, 128, 384]
    },
    'RMM_ESN' : {
        'radius' : [0.5, 0.7, 0.9],
        'sparsity' : [0.1, 0.2, 0.5],
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.],
        'svm_kernel' : ['linear', 'rbf']
    },
    'RMM_CRJ' : {
        'v' : [0.1, 0.3, 0.5],
        'w_c' : [0.1, 0.7, 0.9],
        'w_j' : [0.1, 0.2, 0.4],
        'l' : [4, 8, 16],
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.],
        'svm_kernel' : ['linear', 'rbf']
    },
    'RMM_LMU' : {
        'regul' : [1E-7, 1E-5, 1E-3],
        'C' : [1., 100., 10000.],
        #'T' : [16, 32, 128, 384],
        'svm_kernel' : ['linear', 'rbf']
    }
}

import numpy as np
import rmm2.esn as esn
import rmm2.crj as crj
import rmm2.lmu as lmu
import rmm2.rmm as rmm

# set up a function to initialize an instance for each model
def setup_model(model, m, n, hyperparams):
    # first, set up the correct reservoir and nonlinearity
    if model.endswith('ESN'):
        U, W = esn.initialize_reservoir(m, n, radius = hyperparams['radius'],
                                        sparsity = hyperparams['sparsity'])
        nonlin = np.tanh
    elif model.endswith('CRJ'):
        U = crj.setup_input_weight_matrix(n, m, v = hyperparams['v'])
        W = crj.setup_reservoir_matrix(m, w_c = hyperparams['w_c'],
                                       w_j = hyperparams['w_j'], l = hyperparams['l'])
        nonlin = np.tanh
    elif model.endswith('LMU'):
        degree = int(m/n)-1
        U, W = lmu.initialize_reservoir(n, degree, hyperparams['T'])
        nonlin = lambda x : x
    else:
        raise ValueError('Unknown model: %s' % model)
    # then, set up the model
    if not model.startswith('RMM_'):
        net = esn.ESN(U, W, regul = hyperparams['regul'], input_normalization = False,
                      nonlin = nonlin)
    else:
        net = rmm.RMM(U, W, regul = hyperparams['regul'], input_normalization = False,
                      nonlin = nonlin, C = hyperparams['C'],
                      svm_kernel = hyperparams['svm_kernel'])
    return net

# %% [markdown]
# ## Experiment
#
# After all the hyperparameter setup above we can now iterate over all tasks and
# first perform hyperparameter optimization, followed by the actual experiment.

# %%
import json
import os
import random
import time
from dataset_generators import generate_data
from dataset_generators import _permutation_sampling

# iterate over all tasks
for task_idx in range(len(tasks)):
    task = tasks[task_idx]
    print('------ Task %d of %d: %s -----' % (task_idx+1, len(tasks), task))
    m = num_neurons[task_idx]
    n = ns[task_idx]
    # try to load the selected hyperparameters from file
    hyperparam_path = '%s_hyperparams.json' % task
    if os.path.isfile(hyperparam_path):
        print('loading hyperparameters from %s' % hyperparam_path)
        with open(hyperparam_path, 'r') as hyperparam_file:
            hyperparams = json.load(hyperparam_file)
    else:
        # perform a hyperoptimization where we test R random hyperparameter
        # settings for each model and perform num_repeats repeats to obtain
        # statistics. The hyperparameters with the best mean performance across
        # repeats will be selected
        print('performing hyperparameter optimization (this may take a while)')
        # generate random parameter combination for all models
        hyperparams = {}
        for model in models:
            # initialize a hyperparameter dictionary for each combination
            hyperparams[model] = []
            for r in range(hyper_R):
                hyperparams[model].append({})
            # then iterate over each key and sample the parameter values
            for key in hyperparam_ranges[model]:
                param_range = hyperparam_ranges[model][key]
                param_value_indices = _permutation_sampling(hyper_R, 0, len(param_range)-1)
                for r in range(hyper_R):
                    value = param_range[param_value_indices[r]]
                    hyperparams[model][r][key] = value
            for r in range(hyper_R):
                # set up an extra key for the errors
                hyperparams[model][r]['errors'] = []
                # for the signal_copy dataset, use the 'pseudo' SVM, because everything
                # else takes too long to train
                if task == 'signal_copy' and model.startswith('RMM'):
                    hyperparams[model][r]['svm_kernel'] = 'pseudo'
                # set time horizon for LMU models
                if model.endswith('LMU'):
                    hyperparams[model][r]['T'] = Ts[task_idx]

        for repeat in range(hyper_num_repeats):
            print('--- repeat %d of %d ---' % (repeat+1, hyper_num_repeats))
            # sample training and test data
            Xs, Qs, Ys = generate_data(N, task)
            Xs_test, Qs_test, Ys_test = generate_data(N_test, task)
            # now iterate over all models
            for model in models:
                print('-- model: %s --' % model)
                # and iterate over all parameter combinations for this model
                for params_r in hyperparams[model]:
                    # set up a model instance
                    net = setup_model(model, m, n, params_r)
                    # fit the model to the data
                    if model.startswith('RMM_'):
                        net.fit(Xs, Qs, Ys)
                    else:
                        net.fit(Xs, Ys)
                    # measure the RMSE on the test data
                    mse = 0.
                    for i in range(N_test):
                        Ypred = net.predict(Xs_test[i])
                        mse   += np.mean((Ypred - Ys_test[i]) ** 2)
                    rmse = np.sqrt(mse / N_test)
                    params_r['errors'].append(rmse)
                    print('error: %g' % rmse)
        # write the results to a JSON file
        with open(hyperparam_path, 'w') as hyperparam_file:
            json.dump(hyperparams, hyperparam_file)

    # select best hyperparameters for each model
    hyperparams_opt = {}
    for model in models:
        min_err = np.inf
        for params_r in hyperparams[model]:
            if np.mean(params_r['errors']) < min_err:
                min_err = np.mean(params_r['errors'])
                hyperparams_opt[model] = params_r
        print('\nSelected the following hyper-parameters for %s' % model)
        for key in hyperparams_opt[model]:
            print('%s: %s' % (key, str(hyperparams_opt[model][key])))
    # hyperparameter optimization complete
    
    # ACTUAL EXPERIMENT

    # initialize error and runtime arrays
    errors   = np.zeros((len(models), R))
    runtimes = np.zeros((len(models), R))
    # iterate over all experimental repeats
    for r in range(R):
        print('--- repeat %d of %d ---' % (r+1, R))
        # sample training and test data
        Xs, Qs, Ys = generate_data(N, task)
        Xs_test, Qs_test, Ys_test = generate_data(N_test, task)
        # now iterate over all models
        for model_idx in range(len(models)):
            model = models[model_idx]
            # print('-- model: %s --' % model)
            # set up the model with the best selected hyperparameters
            start_time = time.time()
            net = setup_model(model, m, n, hyperparams_opt[model])
            # fit the model to the data
            if model.startswith('RMM_'):
                net.fit(Xs, Qs, Ys)
            else:
                net.fit(Xs, Ys)
            # measure the RMSE on the test data
            mse = 0.
            for i in range(N_test):
                Ypred = net.predict(Xs_test[i])
                mse   += np.mean((Ypred - Ys_test[i]) ** 2)
            rmse = np.sqrt(mse / N_test)
            runtimes[model_idx, r] = time.time() - start_time
            errors[model_idx, r] = rmse
    # print results
    for model_idx in range(len(models)):
        print('%s: %g +- %g (took %g seconds)' % (models[model_idx], np.mean(errors[model_idx, :]), np.std(errors[model_idx, :]), np.mean(runtimes[model_idx, :])))
    # write results to file
    np.savetxt('%s_errors.csv' % task, errors.T, delimiter='\t', header='\t'.join(models), comments='')
    np.savetxt('%s_runtimes.csv' % task, runtimes.T, delimiter='\t', header='\t'.join(models), comments='')
# Out:
# ------ Task 1 of 4: latch -----
# performing hyperparameter optimization (this may take a while)
# --- repeat 1 of 3 ---
# -- model: ESN --
# error: 0.650006
# error: 1.8574
# error: 0.748828
# error: 0.538785
# error: 0.564488
# error: 0.557255
# error: 0.792649
# error: 1.22745
# error: 0.543965
# error: 2.01097
# error: 0.908025
# error: 0.533619
# error: 0.527513
# error: 0.549726
# error: 0.616828
# error: 0.562745
# error: 0.710813
# error: 0.526645
# error: 0.632329
# error: 0.54988
# -- model: CRJ --
# error: 0.557901
# error: 0.531944
# error: 0.595287
# error: 0.556377
# error: 0.609112
# error: 0.552196
# error: 0.585155
# error: 0.639562
# error: 0.605366
# error: 0.566212
# error: 0.558781
# error: 0.554382
# error: 0.594282
# error: 0.572832
# error: 0.517214
# error: 0.534563
# error: 0.550437
# error: 0.564799
# error: 0.538154
# error: 0.588388
# -- model: LMU --
# error: 0.554904
# error: 0.554903
# error: 0.554916
# error: 0.554903
# error: 0.554904
# error: 0.554916
# error: 0.554904
# error: 0.554903
# error: 0.554916
# error: 0.554916
# error: 0.554904
# error: 0.554903
# error: 0.554903
# error: 0.554916
# error: 0.554904
# error: 0.554916
# error: 0.554904
# error: 0.554903
# error: 0.554904
# error: 0.554903
# -- model: RMM_ESN --
# State prediction recall: 1; precision: 1
# error: 1.59067e-05
# State prediction recall: 0.999898; precision: 0.999898
# error: 6.70859e-08
# State prediction recall: 1; precision: 1
# error: 3.07798e-08
# State prediction recall: 1; precision: 1
# error: 7.54841e-08
# State prediction recall: 0.999898; precision: 0.999898
# error: 8.23892e-08
# State prediction recall: 1; precision: 1
# error: 1.86572e-05
# State prediction recall: 1; precision: 1
# error: 3.13711e-08
# State prediction recall: 1; precision: 1
# error: 2.38555e-05
# State prediction recall: 0.999898; precision: 0.999898
# error: 1.11487e-07
# State prediction recall: 0.999898; precision: 0.999898
# error: 2.14542e-06
# State prediction recall: 1; precision: 1
# error: 3.77353e-08
# State prediction recall: 1; precision: 1
# error: 6.27644e-07
# State prediction recall: 1; precision: 1
# error: 9.16621e-08
# State prediction recall: 1; precision: 1
# error: 1.80044e-05
# State prediction recall: 1; precision: 1
# error: 3.59186e-07
# State prediction recall: 1; precision: 1
# error: 9.2617e-08
# State prediction recall: 1; precision: 1
# error: 4.19445e-07
# State prediction recall: 0.999898; precision: 0.999898
# error: 1.592e-05
# State prediction recall: 1; precision: 1
# error: 6.82523e-08
# State prediction recall: 1; precision: 1
# error: 1.51107e-07
# -- model: RMM_CRJ --
# State prediction recall: 1; precision: 1
# error: 2.6416e-07
# State prediction recall: 1; precision: 1
# error: 5.56775e-08
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 0.999898; precision: 0.999898
# error: 2.39001e-08
# State prediction recall: 1; precision: 1
# error: 4.50116e-07
# State prediction recall: 1; precision: 1
# error: 9.04882e-06
# State prediction recall: 1; precision: 1
# error: 1.66629e-05
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 7.91293e-08
# State prediction recall: 1; precision: 1
# error: 2.6416e-07
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 4.58543e-07
# State prediction recall: 1; precision: 1
# error: 8.18364e-08
# State prediction recall: 1; precision: 1
# error: 3.79925e-05
# State prediction recall: 0.999898; precision: 0.999898
# error: 1.44035e-07
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 7.98417e-08
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 1.24345e-07
# State prediction recall: 1; precision: 1
# error: 1.68133e-05
# -- model: RMM_LMU --
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 2.15249e-07
# State prediction recall: 1; precision: 1
# error: 1.59751e-06
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 1.59751e-06
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 1.59751e-06
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 1.68121e-08
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 2.15249e-07
# State prediction recall: 1; precision: 1
# error: 1.68121e-08
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 1.68121e-08
# State prediction recall: 1; precision: 1
# error: 1.59751e-06
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# State prediction recall: 1; precision: 1
# error: 2.15249e-07
# State prediction recall: 0.972501; precision: 0.972501
# error: 0.698686
# --- repeat 2 of 3 ---
# -- model: ESN --
# error: 0.624424
# error: 0.606327
# error: 0.529763
# error: 0.613705
# error: 0.512444
# error: 0.615237
# error: 0.567463
# error: 0.578974
# error: 0.631058
# error: 0.588338
# error: 0.527807
# error: 0.628882
# error: 0.63193
# error: 0.611645
# error: 0.56898
# error: 0.555887
# error: 0.581743
# error: 0.617529
# error: 0.601064
# error: 0.613573
# -- model: CRJ --
# error: 0.502223
# error: 0.639197
# error: 0.564315
# error: 0.591307
# error: 0.565942
# error: 0.495071
# error: 0.504738
# error: 0.578103
# error: 0.549481
# error: 0.601706
# error: 0.589398
# error: 0.498012
# error: 0.681865
# error: 0.55038
# error: 0.47966
# error: 0.6408
# error: 0.557674
# error: 0.517551
# error: 0.595913
# error: 0.512097
# -- model: LMU --
# error: 0.494553
# error: 0.494555
# error: 0.494604
# error: 0.494555
# error: 0.494553
# error: 0.494604
# error: 0.494553
# error: 0.494555
# error: 0.494604
# error: 0.494604
# error: 0.494553
# error: 0.494555
# error: 0.494555
# error: 0.494604
# error: 0.494553
# error: 0.494604
# error: 0.494553
# error: 0.494555
# error: 0.494553
# error: 0.494555
# -- model: RMM_ESN --
# State prediction recall: 1; precision: 1
# error: 3.63905e-06
# State prediction recall: 1; precision: 1
# error: 1.90235e-07
# State prediction recall: 1; precision: 1
# error: 4.90912e-09
# State prediction recall: 1; precision: 1
# error: 1.41917e-07
# State prediction recall: 1; precision: 1
# error: 1.85095e-08
# State prediction recall: 1; precision: 1
# error: 4.26907e-05
# State prediction recall: 1; precision: 1
# error: 7.63111e-11
# State prediction recall: 1; precision: 1
# error: 1.90802e-05
# State prediction recall: 1; precision: 1
# error: 2.88438e-07
# State prediction recall: 1; precision: 1
# error: 8.15562e-06
# State prediction recall: 1; precision: 1
# error: 5.95622e-09
# State prediction recall: 1; precision: 1
# error: 1.34295e-07
# State prediction recall: 1; precision: 1
# error: 1.16547e-08
# State prediction recall: 1; precision: 1
# error: 3.36075e-05
# State prediction recall: 1; precision: 1
# error: 6.80228e-08
# State prediction recall: 1; precision: 1
# error: 1.17861e-08
# State prediction recall: 1; precision: 1
# error: 1.68965e-08
# State prediction recall: 1; precision: 1
# error: 1.23431e-06
# State prediction recall: 1; precision: 1
# error: 1.17764e-08
# State prediction recall: 1; precision: 1
# error: 2.09271e-07
# -- model: RMM_CRJ --
# State prediction recall: 1; precision: 1
# error: 3.14139e-07
# State prediction recall: 1; precision: 1
# error: 2.93754e-08
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 3.14139e-07
# State prediction recall: 1; precision: 1
# error: 2.41139e-07
# State prediction recall: 1; precision: 1
# error: 1.93295e-05
# State prediction recall: 1; precision: 1
# error: 3.49222e-05
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 2.93754e-08
# State prediction recall: 1; precision: 1
# error: 3.14139e-07
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 2.41139e-07
# State prediction recall: 1; precision: 1
# error: 2.93754e-08
# State prediction recall: 1; precision: 1
# error: 3.49222e-05
# State prediction recall: 1; precision: 1
# error: 2.52659e-08
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 3.14139e-07
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 3.14139e-07
# State prediction recall: 1; precision: 1
# error: 2.41139e-07
# -- model: RMM_LMU --
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 2.77876e-08
# State prediction recall: 1; precision: 1
# error: 1.44273e-06
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 1.44273e-06
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 1.44273e-06
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 1.26675e-08
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 2.77876e-08
# State prediction recall: 1; precision: 1
# error: 1.26675e-08
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 1.26675e-08
# State prediction recall: 1; precision: 1
# error: 1.44273e-06
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# State prediction recall: 1; precision: 1
# error: 2.77876e-08
# State prediction recall: 0.972102; precision: 0.972102
# error: 0.729559
# --- repeat 3 of 3 ---
# -- model: ESN --
# error: 0.555344
# error: 0.51632
# error: 0.525251
# error: 0.551744
# error: 0.485042
# error: 0.538536
# error: 0.502669
# error: 0.526301
# error: 0.58157
# error: 0.521598
# error: 0.52934
# error: 0.576554
# error: 0.582411
# error: 0.536291
# error: 0.559828
# error: 0.481826
# error: 0.51441
# error: 0.544314
# error: 0.555218
# error: 0.530489
# -- model: CRJ --
# error: 0.519229
# error: 0.585364
# error: 0.544282
# error: 0.530789
# error: 0.539144
# error: 0.495628
# error: 0.487297
# error: 0.526944
# error: 0.550315
# error: 0.543791
# error: 0.530294
# error: 0.539396
# error: 0.658174
# error: 0.537499
# error: 0.500387
# error: 0.588788
# error: 0.504727
# error: 0.537063
# error: 0.531943
# error: 0.516934
# -- model: LMU --
# error: 0.528982
# error: 0.528987
# error: 0.528997
# error: 0.528987
# error: 0.528982
# error: 0.528997
# error: 0.528982
# error: 0.528987
# error: 0.528997
# error: 0.528997
# error: 0.528982
# error: 0.528987
# error: 0.528987
# error: 0.528997
# error: 0.528982
# error: 0.528997
# error: 0.528982
# error: 0.528987
# error: 0.528982
# error: 0.528987
# -- model: RMM_ESN --
# State prediction recall: 1; precision: 1
# error: 8.87152e-07
# State prediction recall: 1; precision: 1
# error: 4.46697e-08
# State prediction recall: 1; precision: 1
# error: 3.46979e-09
# State prediction recall: 1; precision: 1
# error: 6.55767e-08
# State prediction recall: 1; precision: 1
# error: 1.51758e-08
# State prediction recall: 1; precision: 1
# error: 2.24443e-05
# State prediction recall: 1; precision: 1
# error: 7.5047e-09
# State prediction recall: 1; precision: 1
# error: 8.62922e-06
# State prediction recall: 1; precision: 1
# error: 8.26191e-08
# State prediction recall: 1; precision: 1
# error: 1.49088e-06
# State prediction recall: 1; precision: 1
# error: 9.45231e-09
# State prediction recall: 1; precision: 1
# error: 3.31865e-08
# State prediction recall: 1; precision: 1
# error: 1.35865e-08
# State prediction recall: 1; precision: 1
# error: 1.42631e-05
# State prediction recall: 1; precision: 1
# error: 2.04503e-07
# State prediction recall: 1; precision: 1
# error: 1.33985e-08
# State prediction recall: 1; precision: 1
# error: 2.15092e-07
# State prediction recall: 1; precision: 1
# error: 4.1587e-07
# State prediction recall: 1; precision: 1
# error: 1.29361e-08
# State prediction recall: 1; precision: 1
# error: 1.64878e-07
# -- model: RMM_CRJ --
# State prediction recall: 1; precision: 1
# error: 3.00906e-08
# State prediction recall: 1; precision: 1
# error: 3.06017e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 3.00906e-08
# State prediction recall: 1; precision: 1
# error: 2.41515e-07
# State prediction recall: 1; precision: 1
# error: 3.55373e-05
# State prediction recall: 1; precision: 1
# error: 6.87539e-05
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 3.06017e-08
# State prediction recall: 1; precision: 1
# error: 3.00906e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 2.41515e-07
# State prediction recall: 1; precision: 1
# error: 3.06017e-08
# State prediction recall: 1; precision: 1
# error: 6.87539e-05
# State prediction recall: 1; precision: 1
# error: 1.49751e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 3.00906e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 3.00906e-08
# State prediction recall: 1; precision: 1
# error: 2.41515e-07
# -- model: RMM_LMU --
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 6.66386e-08
# State prediction recall: 1; precision: 1
# error: 1.44447e-06
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 1.44447e-06
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 1.44447e-06
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 1.46748e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 6.66386e-08
# State prediction recall: 1; precision: 1
# error: 1.46748e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 1.46748e-08
# State prediction recall: 1; precision: 1
# error: 1.44447e-06
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
# State prediction recall: 1; precision: 1
# error: 6.66386e-08
# State prediction recall: 0.971395; precision: 0.971395
# error: 0.731964
#
# Selected the following hyper-parameters for ESN
# radius: 0.9
# sparsity: 0.1
# regul: 1e-07
# errors: [0.564487943050526, 0.5124443006275852, 0.4850424296936987]
#
# Selected the following hyper-parameters for CRJ
# v: 0.5
# w_c: 0.9
# w_j: 0.4
# l: 16
# regul: 1e-07
# errors: [0.5172141977882222, 0.47966022019389803, 0.5003866237969719]
#
# Selected the following hyper-parameters for LMU
# regul: 1e-07
# errors: [0.5549043146817274, 0.4945529092463022, 0.5289815217282199]
# T: 256
#
# Selected the following hyper-parameters for RMM_ESN
# radius: 0.9
# sparsity: 0.5
# regul: 0.001
# C: 10000.0
# svm_kernel: rbf
# errors: [3.1371068124449944e-08, 7.631108815465734e-11, 7.504695927015374e-09]
#
# Selected the following hyper-parameters for RMM_CRJ
# v: 0.3
# w_c: 0.9
# w_j: 0.2
# l: 4
# regul: 0.001
# C: 10000.0
# svm_kernel: rbf
# errors: [5.5677454176444575e-08, 2.93754166644808e-08, 3.0601745357000445e-08]
#
# Selected the following hyper-parameters for RMM_LMU
# regul: 1e-05
# C: 10000.0
# svm_kernel: rbf
# errors: [1.6812143182448694e-08, 1.2667479290251305e-08, 1.467481033904004e-08]
# T: 256
# --- repeat 1 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 2 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 3 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 4 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 5 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 6 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 7 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 8 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 9 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 10 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 11 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 12 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 13 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 14 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 15 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 16 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 17 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 18 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 19 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# --- repeat 20 of 20 ---
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# State prediction recall: 1; precision: 1
# ESN: 0.66405 +- 0.28974 (took 0.0868942 seconds)
# CRJ: 0.504464 +- 0.037417 (took 0.0851943 seconds)
# LMU: 0.526703 +- 0.0173051 (took 0.110729 seconds)
# RMM_ESN: 1.12523e-08 +- 1.00776e-08 (took 0.190409 seconds)
# RMM_CRJ: 3.63773e-08 +- 1.56944e-08 (took 0.178002 seconds)
# RMM_LMU: 1.52504e-08 +- 1.96656e-09 (took 0.200679 seconds)
# ------ Task 2 of 4: copy -----
# performing hyperparameter optimization (this may take a while)
# --- repeat 1 of 3 ---
# -- model: ESN --
# error: 0.378468
# error: 0.382372
# error: 0.388432
# error: 0.36969
# error: 0.37186
# error: 0.396363
# error: 0.376484
# error: 0.393668
# error: 0.385576
# error: 0.377598
# error: 0.39295
# error: 0.376636
# error: 0.372178
# error: 0.39556
# error: 0.379399
# error: 0.366553
# error: 0.389901
# error: 0.397126
# error: 0.394683
# error: 0.381727
# -- model: CRJ --
# error: 0.46023
# error: 0.472301
# error: 0.46194
# error: 0.453982
# error: 0.472294
# error: 0.455988
# error: 0.462457
# error: 0.445304
# error: 0.483431
# error: 0.478433
# error: 0.458657
# error: 0.448333
# error: 0.445696
# error: 0.456117
# error: 0.472084
# error: 0.455961
# error: 0.470502
# error: 0.467298
# error: 0.466202
# error: 0.467051
# -- model: LMU --
# error: 0.330973
# error: 0.330504
# error: 0.330988
# error: 0.330973
# error: 0.330988
# error: 0.330504
# error: 0.330988
# error: 0.330973
# error: 0.330504
# error: 0.330988
# error: 0.330973
# error: 0.330504
# error: 0.330973
# error: 0.330504
# error: 0.330988
# error: 0.330973
# error: 0.330988
# error: 0.330504
# error: 0.330504
# error: 0.330973
# -- model: RMM_ESN --
# State prediction recall: 0.794258; precision: 0.794258
# error: 0.350456
# State prediction recall: 1; precision: 1
# error: 0.391
# State prediction recall: 1; precision: 1
# error: 0.406205
# State prediction recall: 0.910048; precision: 0.910048
# error: 0.364351
# State prediction recall: 1; precision: 1
# error: 0.389811
# State prediction recall: 0.883732; precision: 0.883732
# error: 0.367161
# State prediction recall: 0.518182; precision: 0.518182
# error: 0.409138
# State prediction recall: 0.900957; precision: 0.900957
# error: 0.396163
# State prediction recall: 1; precision: 1
# error: 0.41667
# State prediction recall: 0.89378; precision: 0.89378
# error: 0.399032
# State prediction recall: 1; precision: 1
# error: 0.389902
# State prediction recall: 0.825837; precision: 0.825837
# error: 0.387494
# State prediction recall: 0.901914; precision: 0.901914
# error: 0.424779
# State prediction recall: 0.44067; precision: 0.44067
# error: 0.442431
# State prediction recall: 0.909569; precision: 0.909569
# error: 0.389362
# State prediction recall: 1; precision: 1
# error: 0.411161
# State prediction recall: 1; precision: 1
# error: 0.405919
# State prediction recall: 0.813876; precision: 0.813876
# error: 0.376152
# State prediction recall: 0.897608; precision: 0.897608
# error: 0.43785
# State prediction recall: 1; precision: 1
# error: 0.395555
# -- model: RMM_CRJ --
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# State prediction recall: 0.979904; precision: 0.979904
# error: 0.493503
# State prediction recall: 0.826316; precision: 0.826316
# error: 0.524623
# State prediction recall: 0.998086; precision: 0.998086
# error: 0.527704
# State prediction recall: 0.542105; precision: 0.542105
# error: 0.493508
# State prediction recall: 0.998086; precision: 0.998086
# error: 0.463222
# State prediction recall: 0.65311; precision: 0.65311
# error: 0.884699
# State prediction recall: 1; precision: 1
# error: 0.45299
# State prediction recall: 0.343541; precision: 0.343541
# error: 0.476869
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# State prediction recall: 0.947368; precision: 0.947368
# error: 0.589613
# State prediction recall: 1; precision: 1
# error: 0.684673
# State prediction recall: 0.412919; precision: 0.412919
# error: 0.452001
# State prediction recall: 0.537799; precision: 0.537799
# error: 0.489204
# State prediction recall: 0.991388; precision: 0.991388
# error: 0.639925
# State prediction recall: 0.37512; precision: 0.37512
# error: 0.44387
# State prediction recall: 1; precision: 1
# error: 0.485011
# State prediction recall: 0.848325; precision: 0.848325
# error: 0.449967
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# State prediction recall: 0.96555; precision: 0.96555
# error: 0.741676
# State prediction recall: 0.466507; precision: 0.466507
# error: 0.465552
# State prediction recall: 0.955502; precision: 0.955502
# error: 0.495975
# State prediction recall: 0.41244; precision: 0.41244
# error: 0.583674
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.445881
# State prediction recall: 1; precision: 1
# error: 0.104583
# State prediction recall: 1; precision: 1
# error: 0.445874
# State prediction recall: 1; precision: 1
# error: 0.0433013
# State prediction recall: 0.990431; precision: 0.990431
# error: 0.457413
# State prediction recall: 1; precision: 1
# error: 0.043301
# State prediction recall: 1; precision: 1
# error: 0.0433013
# State prediction recall: 1; precision: 1
# error: 0.445874
# State prediction recall: 1; precision: 1
# error: 0.104583
# State prediction recall: 0.990431; precision: 0.990431
# error: 0.457406
# State prediction recall: 1; precision: 1
# error: 0.445881
# State prediction recall: 1; precision: 1
# error: 0.0433013
# State prediction recall: 1; precision: 1
# error: 0.445881
# State prediction recall: 1; precision: 1
# error: 0.104583
# State prediction recall: 1; precision: 1
# error: 0.445881
# State prediction recall: 1; precision: 1
# error: 0.043301
# State prediction recall: 1; precision: 1
# error: 0.445881
# State prediction recall: 1; precision: 1
# error: 0.104583
# State prediction recall: 1; precision: 1
# error: 0.445874
# State prediction recall: 1; precision: 1
# error: 0.104583
# --- repeat 2 of 3 ---
# -- model: ESN --
# error: 0.377558
# error: 0.416551
# error: 0.440546
# error: 0.394003
# error: 0.423399
# error: 0.43421
# error: 0.396588
# error: 0.434273
# error: 0.412051
# error: 0.418962
# error: 0.428358
# error: 0.396059
# error: 0.39083
# error: 0.429455
# error: 0.41779
# error: 0.38795
# error: 0.420966
# error: 0.443614
# error: 0.390585
# error: 0.43556
# -- model: CRJ --
# error: 0.456725
# error: 0.476456
# error: 0.470815
# error: 0.457623
# error: 0.504318
# error: 0.453382
# error: 0.470064
# error: 0.446635
# error: 0.514054
# error: 0.51579
# error: 0.459298
# error: 0.450457
# error: 0.44665
# error: 0.461815
# error: 0.476223
# error: 0.454413
# error: 0.478316
# error: 0.478585
# error: 0.458718
# error: 0.473385
# -- model: LMU --
# error: 0.345034
# error: 0.34416
# error: 0.345782
# error: 0.345034
# error: 0.345782
# error: 0.34416
# error: 0.345782
# error: 0.345034
# error: 0.34416
# error: 0.345782
# error: 0.345034
# error: 0.34416
# error: 0.345034
# error: 0.34416
# error: 0.345782
# error: 0.345034
# error: 0.345782
# error: 0.34416
# error: 0.34416
# error: 0.345034
# -- model: RMM_ESN --
# State prediction recall: 0.808066; precision: 0.808066
# error: 0.458405
# State prediction recall: 1; precision: 1
# error: 0.455155
# State prediction recall: 1; precision: 1
# error: 0.465346
# State prediction recall: 0.942663; precision: 0.942663
# error: 0.473052
# State prediction recall: 1; precision: 1
# error: 0.463486
# State prediction recall: 0.866861; precision: 0.866861
# error: 0.440358
# State prediction recall: 0.502915; precision: 0.502915
# error: 0.467169
# State prediction recall: 0.907677; precision: 0.907677
# error: 0.445004
# State prediction recall: 1; precision: 1
# error: 0.483394
# State prediction recall: 0.886783; precision: 0.886783
# error: 0.469561
# State prediction recall: 1; precision: 1
# error: 0.466841
# State prediction recall: 0.852284; precision: 0.852284
# error: 0.464208
# State prediction recall: 0.889213; precision: 0.889213
# error: 0.449376
# State prediction recall: 0.421283; precision: 0.421283
# error: 0.484438
# State prediction recall: 0.909621; precision: 0.909621
# error: 0.459041
# State prediction recall: 1; precision: 1
# error: 0.474418
# State prediction recall: 1; precision: 1
# error: 0.448741
# State prediction recall: 0.844509; precision: 0.844509
# error: 0.45229
# State prediction recall: 0.908163; precision: 0.908163
# error: 0.485061
# State prediction recall: 1; precision: 1
# error: 0.486087
# -- model: RMM_CRJ --
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# State prediction recall: 0.984937; precision: 0.984937
# error: 0.567906
# State prediction recall: 0.831876; precision: 0.831876
# error: 1.43789
# State prediction recall: 0.998542; precision: 0.998542
# error: 0.504682
# State prediction recall: 0.54276; precision: 0.54276
# error: 0.594984
# State prediction recall: 0.998542; precision: 0.998542
# error: 0.512499
# State prediction recall: 0.664723; precision: 0.664723
# error: 1.30414
# State prediction recall: 1; precision: 1
# error: 0.48636
# State prediction recall: 0.367833; precision: 0.367833
# error: 0.519098
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# State prediction recall: 0.956268; precision: 0.956268
# error: 0.75314
# State prediction recall: 1; precision: 1
# error: 0.751393
# State prediction recall: 0.420797; precision: 0.420797
# error: 0.475778
# State prediction recall: 0.547619; precision: 0.547619
# error: 0.616592
# State prediction recall: 0.990768; precision: 0.990768
# error: 1.12173
# State prediction recall: 0.393586; precision: 0.393586
# error: 0.488852
# State prediction recall: 1; precision: 1
# error: 0.558903
# State prediction recall: 0.866375; precision: 0.866375
# error: 0.498245
# State prediction recall: 0.97036; precision: 0.97036
# error: 0.957612
# State prediction recall: 0.48105; precision: 0.48105
# error: 0.495717
# State prediction recall: 0.95724; precision: 0.95724
# error: 0.560981
# State prediction recall: 0.428571; precision: 0.428571
# error: 0.611725
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.381816
# State prediction recall: 1; precision: 1
# error: 0.0887438
# State prediction recall: 1; precision: 1
# error: 0.381811
# State prediction recall: 1; precision: 1
# error: 0.119523
# State prediction recall: 0.990282; precision: 0.990282
# error: 0.44702
# State prediction recall: 1; precision: 1
# error: 0.0845307
# State prediction recall: 1; precision: 1
# error: 0.0845154
# State prediction recall: 1; precision: 1
# error: 0.381811
# State prediction recall: 1; precision: 1
# error: 0.0887438
# State prediction recall: 0.990282; precision: 0.990282
# error: 0.447015
# State prediction recall: 1; precision: 1
# error: 0.381815
# State prediction recall: 1; precision: 1
# error: 0.0845154
# State prediction recall: 1; precision: 1
# error: 0.381815
# State prediction recall: 1; precision: 1
# error: 0.0887447
# State prediction recall: 1; precision: 1
# error: 0.381816
# State prediction recall: 1; precision: 1
# error: 0.0845307
# State prediction recall: 1; precision: 1
# error: 0.381816
# State prediction recall: 1; precision: 1
# error: 0.0887438
# State prediction recall: 1; precision: 1
# error: 0.381811
# State prediction recall: 1; precision: 1
# error: 0.0887438
# --- repeat 3 of 3 ---
# -- model: ESN --
# error: 0.385086
# error: 0.391094
# error: 0.404691
# error: 0.383277
# error: 0.395775
# error: 0.405415
# error: 0.37999
# error: 0.403281
# error: 0.395987
# error: 0.393227
# error: 0.413184
# error: 0.371709
# error: 0.389378
# error: 0.401999
# error: 0.396475
# error: 0.394453
# error: 0.391953
# error: 0.403874
# error: 0.398023
# error: 0.409003
# -- model: CRJ --
# error: 0.468906
# error: 0.488384
# error: 0.461522
# error: 0.466965
# error: 0.485499
# error: 0.473484
# error: 0.473615
# error: 0.46505
# error: 0.501306
# error: 0.496873
# error: 0.468311
# error: 0.466089
# error: 0.453304
# error: 0.472667
# error: 0.488106
# error: 0.462929
# error: 0.473679
# error: 0.491324
# error: 0.470938
# error: 0.493809
# -- model: LMU --
# error: 0.344008
# error: 0.343614
# error: 0.345384
# error: 0.344008
# error: 0.345384
# error: 0.343614
# error: 0.345384
# error: 0.344008
# error: 0.343614
# error: 0.345384
# error: 0.344008
# error: 0.343614
# error: 0.344008
# error: 0.343614
# error: 0.345384
# error: 0.344008
# error: 0.345384
# error: 0.343614
# error: 0.343614
# error: 0.344008
# -- model: RMM_ESN --
# State prediction recall: 0.769011; precision: 0.769011
# error: 0.41529
# State prediction recall: 1; precision: 1
# error: 0.457823
# State prediction recall: 1; precision: 1
# error: 0.43781
# State prediction recall: 0.876901; precision: 0.876901
# error: 0.432855
# State prediction recall: 1; precision: 1
# error: 0.44008
# State prediction recall: 0.826996; precision: 0.826996
# error: 0.421349
# State prediction recall: 0.495247; precision: 0.495247
# error: 0.478238
# State prediction recall: 0.855513; precision: 0.855513
# error: 0.419804
# State prediction recall: 1; precision: 1
# error: 0.425138
# State prediction recall: 0.889734; precision: 0.889734
# error: 0.413659
# State prediction recall: 1; precision: 1
# error: 0.447383
# State prediction recall: 0.836977; precision: 0.836977
# error: 0.364303
# State prediction recall: 0.89211; precision: 0.89211
# error: 0.420348
# State prediction recall: 0.420627; precision: 0.420627
# error: 0.472131
# State prediction recall: 0.871673; precision: 0.871673
# error: 0.441195
# State prediction recall: 1; precision: 1
# error: 0.42699
# State prediction recall: 1; precision: 1
# error: 0.453113
# State prediction recall: 0.817966; precision: 0.817966
# error: 0.399686
# State prediction recall: 0.875; precision: 0.875
# error: 0.399853
# State prediction recall: 1; precision: 1
# error: 0.456484
# -- model: RMM_CRJ --
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# State prediction recall: 0.984791; precision: 0.984791
# error: 0.537532
# State prediction recall: 0.815589; precision: 0.815589
# error: 0.872757
# State prediction recall: 1; precision: 1
# error: 0.50013
# State prediction recall: 0.548954; precision: 0.548954
# error: 0.539442
# State prediction recall: 0.999049; precision: 0.999049
# error: 0.497459
# State prediction recall: 0.659221; precision: 0.659221
# error: 1.11272
# State prediction recall: 1; precision: 1
# error: 0.502647
# State prediction recall: 0.355038; precision: 0.355038
# error: 0.528261
# State prediction recall: 0.946293; precision: 0.946293
# error: 0.960377
# State prediction recall: 1; precision: 1
# error: 0.806349
# State prediction recall: 0.420627; precision: 0.420627
# error: 0.480647
# State prediction recall: 0.54943; precision: 0.54943
# error: 0.543671
# State prediction recall: 0.987643; precision: 0.987643
# error: 0.714622
# State prediction recall: 0.382605; precision: 0.382605
# error: 0.506567
# State prediction recall: 1; precision: 1
# error: 0.537986
# State prediction recall: 0.857414; precision: 0.857414
# error: 0.470728
# /usr/lib64/python3.9/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# State prediction recall: 0.974335; precision: 0.974335
# error: 1.37292
# State prediction recall: 0.460076; precision: 0.460076
# error: 0.498358
# State prediction recall: 0.948194; precision: 0.948194
# error: 0.551911
# State prediction recall: 0.41635; precision: 0.41635
# error: 0.556861
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.368126
# State prediction recall: 1; precision: 1
# error: 5.50633e-06
# State prediction recall: 1; precision: 1
# error: 0.368123
# State prediction recall: 1; precision: 1
# error: 0.0829156
# State prediction recall: 0.990494; precision: 0.990494
# error: 0.412811
# State prediction recall: 1; precision: 1
# error: 0.0829141
# State prediction recall: 1; precision: 1
# error: 0.0829156
# State prediction recall: 1; precision: 1
# error: 0.368123
# State prediction recall: 1; precision: 1
# error: 5.50633e-06
# State prediction recall: 0.990494; precision: 0.990494
# error: 0.412807
# State prediction recall: 1; precision: 1
# error: 0.368126
# State prediction recall: 1; precision: 1
# error: 0.0829156
# State prediction recall: 1; precision: 1
# error: 0.368126
# State prediction recall: 1; precision: 1
# error: 0.000228408
# State prediction recall: 1; precision: 1
# error: 0.368126
# State prediction recall: 1; precision: 1
# error: 0.0829141
# State prediction recall: 1; precision: 1
# error: 0.368126
# State prediction recall: 1; precision: 1
# error: 5.50633e-06
# State prediction recall: 1; precision: 1
# error: 0.368123
# State prediction recall: 1; precision: 1
# error: 5.50633e-06
#
# Selected the following hyper-parameters for ESN
# radius: 0.9
# sparsity: 0.1
# regul: 1e-05
# errors: [0.3784678835350523, 0.37755783669058995, 0.3850861526385361]
#
# Selected the following hyper-parameters for CRJ
# v: 0.1
# w_c: 0.1
# w_j: 0.4
# l: 4
# regul: 1e-05
# errors: [0.44569614267247304, 0.4466496695040734, 0.45330388440645186]
#
# Selected the following hyper-parameters for LMU
# regul: 0.001
# errors: [0.33050438396422677, 0.34416000387385837, 0.3436136347872697]
# T: 24
#
# Selected the following hyper-parameters for RMM_ESN
# radius: 0.7
# sparsity: 0.2
# regul: 0.001
# C: 1.0
# svm_kernel: linear
# errors: [0.3874944268561582, 0.46420750886742457, 0.3643025259547993]
#
# Selected the following hyper-parameters for RMM_CRJ
# v: 0.1
# w_c: 0.1
# w_j: 0.1
# l: 4
# regul: 1e-05
# C: 100.0
# svm_kernel: linear
# errors: [0.45200103507922573, 0.4757776595305787, 0.4806468176175816]
#
# Selected the following hyper-parameters for RMM_LMU
# regul: 1e-05
# C: 1.0
# svm_kernel: linear
# errors: [0.10458250794471902, 0.0887437912145135, 5.506330874800856e-06]
# T: 24
# --- repeat 1 of 20 ---
# State prediction recall: 0.817391; precision: 0.817391
# State prediction recall: 0.427053; precision: 0.427053
# State prediction recall: 1; precision: 1
# --- repeat 2 of 20 ---
# State prediction recall: 0.821012; precision: 0.821012
# State prediction recall: 0.430447; precision: 0.430447
# State prediction recall: 1; precision: 1
# --- repeat 3 of 20 ---
# State prediction recall: 0.845745; precision: 0.845745
# State prediction recall: 0.423598; precision: 0.423598
# State prediction recall: 1; precision: 1
# --- repeat 4 of 20 ---
# State prediction recall: 0.829797; precision: 0.829797
# State prediction recall: 0.415622; precision: 0.415622
# State prediction recall: 1; precision: 1
# --- repeat 5 of 20 ---
# State prediction recall: 0.836338; precision: 0.836338
# State prediction recall: 0.414611; precision: 0.414611
# State prediction recall: 1; precision: 1
# --- repeat 6 of 20 ---
# State prediction recall: 0.843658; precision: 0.843658
# State prediction recall: 0.433628; precision: 0.433628
# State prediction recall: 1; precision: 1
# --- repeat 7 of 20 ---
# State prediction recall: 0.8282; precision: 0.8282
# State prediction recall: 0.42589; precision: 0.42589
# State prediction recall: 1; precision: 1
# --- repeat 8 of 20 ---
# State prediction recall: 0.82805; precision: 0.82805
# State prediction recall: 0.417867; precision: 0.417867
# State prediction recall: 1; precision: 1
# --- repeat 9 of 20 ---
# State prediction recall: 0.854932; precision: 0.854932
# State prediction recall: 0.440522; precision: 0.440522
# State prediction recall: 1; precision: 1
# --- repeat 10 of 20 ---
# State prediction recall: 0.834619; precision: 0.834619
# State prediction recall: 0.419961; precision: 0.419961
# State prediction recall: 1; precision: 1
# --- repeat 11 of 20 ---
# State prediction recall: 0.817096; precision: 0.817096
# State prediction recall: 0.428844; precision: 0.428844
# State prediction recall: 1; precision: 1
# --- repeat 12 of 20 ---
# State prediction recall: 0.81561; precision: 0.81561
# State prediction recall: 0.421463; precision: 0.421463
# State prediction recall: 1; precision: 1
# --- repeat 13 of 20 ---
# State prediction recall: 0.833175; precision: 0.833175
# State prediction recall: 0.408745; precision: 0.408745
# State prediction recall: 1; precision: 1
# --- repeat 14 of 20 ---
# State prediction recall: 0.84679; precision: 0.84679
# State prediction recall: 0.435311; precision: 0.435311
# State prediction recall: 1; precision: 1
# --- repeat 15 of 20 ---
# State prediction recall: 0.832075; precision: 0.832075
# State prediction recall: 0.412736; precision: 0.412736
# State prediction recall: 1; precision: 1
# --- repeat 16 of 20 ---
# State prediction recall: 0.85126; precision: 0.85126
# State prediction recall: 0.436531; precision: 0.436531
# State prediction recall: 1; precision: 1
# --- repeat 17 of 20 ---
# State prediction recall: 0.810993; precision: 0.810993
# State prediction recall: 0.419479; precision: 0.419479
# State prediction recall: 1; precision: 1
# --- repeat 18 of 20 ---
# State prediction recall: 0.844143; precision: 0.844143
# State prediction recall: 0.429816; precision: 0.429816
# State prediction recall: 1; precision: 1
# --- repeat 19 of 20 ---
# State prediction recall: 0.845077; precision: 0.845077
# State prediction recall: 0.431467; precision: 0.431467
# State prediction recall: 1; precision: 1
# --- repeat 20 of 20 ---
# State prediction recall: 0.836605; precision: 0.836605
# State prediction recall: 0.424436; precision: 0.424436
# State prediction recall: 1; precision: 1
# ESN: 0.387676 +- 0.0171067 (took 0.0942399 seconds)
# CRJ: 0.450262 +- 0.00928632 (took 0.0339098 seconds)
# LMU: 0.339729 +- 0.00752306 (took 0.0409122 seconds)
# RMM_ESN: 0.430981 +- 0.0284502 (took 1.8332 seconds)
# RMM_CRJ: 0.475141 +- 0.0237936 (took 2.77875 seconds)
# RMM_LMU: 0.0861762 +- 0.0588359 (took 0.653109 seconds)
# ------ Task 3 of 4: repeat_copy -----
# performing hyperparameter optimization (this may take a while)
# --- repeat 1 of 3 ---
# -- model: ESN --
# error: 0.450876
# error: 0.488717
# error: 0.42811
# error: 0.436286
# error: 0.45743
# error: 0.481719
# error: 0.445072
# error: 0.491477
# error: 0.458304
# error: 0.458155
# error: 0.464823
# error: 0.497049
# error: 0.478642
# error: 0.439202
# error: 0.461137
# error: 0.427211
# error: 0.484382
# error: 0.455078
# error: 0.452064
# error: 0.491237
# -- model: CRJ --
# error: 0.505526
# error: 0.478378
# error: 0.461744
# error: 0.476147
# error: 0.481304
# error: 0.48997
# error: 0.450344
# error: 0.500205
# error: 0.519366
# error: 0.512517
# error: 0.461743
# error: 0.494779
# error: 0.463922
# error: 0.516
# error: 0.478449
# error: 0.478973
# error: 0.477659
# error: 0.471066
# error: 0.516577
# error: 0.493182
# -- model: LMU --
# error: 0.45559
# error: 0.451569
# error: 0.46127
# error: 0.451569
# error: 0.46127
# error: 0.45559
# error: 0.45559
# error: 0.451569
# error: 0.46127
# error: 0.46127
# error: 0.45559
# error: 0.451569
# error: 0.45559
# error: 0.46127
# error: 0.451569
# error: 0.46127
# error: 0.45559
# error: 0.451569
# error: 0.45559
# error: 0.46127
# -- model: RMM_ESN --
# State prediction recall: 1; precision: 1
# error: 0.428649
# State prediction recall: 0.898901; precision: 0.898901
# error: 0.459076
# State prediction recall: 1; precision: 1
# error: 0.452123
# State prediction recall: 0.932958; precision: 0.932958
# error: 0.46117
# State prediction recall: 1; precision: 1
# error: 0.45256
# State prediction recall: 1; precision: 1
# error: 0.39571
# State prediction recall: 1; precision: 1
# error: 0.43647
# State prediction recall: 0.99115; precision: 0.99115
# error: 0.366751
# State prediction recall: 1; precision: 1
# error: 0.403205
# State prediction recall: 1; precision: 1
# error: 0.419008
# State prediction recall: 0.900241; precision: 0.900241
# error: 0.466597
# State prediction recall: 1; precision: 1
# error: 0.434912
# State prediction recall: 1; precision: 1
# error: 0.428582
# State prediction recall: 1; precision: 1
# error: 0.408127
# State prediction recall: 0.993832; precision: 0.993832
# error: 0.403237
# State prediction recall: 1; precision: 1
# error: 0.441976
# State prediction recall: 0.980424; precision: 0.980424
# error: 0.362964
# State prediction recall: 1; precision: 1
# error: 0.409192
# State prediction recall: 0.875838; precision: 0.875838
# error: 0.481593
# State prediction recall: 1; precision: 1
# error: 0.475356
# -- model: RMM_CRJ --
# State prediction recall: 0.784393; precision: 0.784393
# error: 0.434292
# State prediction recall: 0.848485; precision: 0.848485
# error: 0.925253
# State prediction recall: 0.999464; precision: 0.999464
# error: 2.83627
# State prediction recall: 0.999464; precision: 0.999464
# error: 0.668045
# State prediction recall: 0.727809; precision: 0.727809
# error: 0.52825
# State prediction recall: 0.836149; precision: 0.836149
# error: 0.958406
# State prediction recall: 0.999464; precision: 0.999464
# error: 1.65919
# State prediction recall: 0.994368; precision: 0.994368
# error: 0.652232
# State prediction recall: 0.779834; precision: 0.779834
# error: 0.457366
# State prediction recall: 0.999464; precision: 0.999464
# error: 0.69296
# State prediction recall: 0.581389; precision: 0.581389
# error: 0.691989
# State prediction recall: 0.999464; precision: 0.999464
# error: 0.70279
# State prediction recall: 0.999464; precision: 0.999464
# error: 1.38312
# State prediction recall: 0.999464; precision: 0.999464
# error: 0.709811
# State prediction recall: 0.496916; precision: 0.496916
# error: 0.514971
# State prediction recall: 0.81845; precision: 0.81845
# error: 0.447919
# State prediction recall: 0.931349; precision: 0.931349
# error: 0.690379
# State prediction recall: 0.999464; precision: 0.999464
# error: 3.57216
# State prediction recall: 0.656744; precision: 0.656744
# error: 0.493143
# State prediction recall: 0.999464; precision: 0.999464
# error: 2.77745
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.355654
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.355655
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.355654
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.355655
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.16241
# State prediction recall: 1; precision: 1
# error: 0.355654
# State prediction recall: 1; precision: 1
# error: 0.355655
# State prediction recall: 1; precision: 1
# error: 0.143586
# State prediction recall: 1; precision: 1
# error: 0.355655
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.143586
# State prediction recall: 1; precision: 1
# error: 0.355654
# State prediction recall: 1; precision: 1
# error: 0.355655
# State prediction recall: 1; precision: 1
# error: 0.162413
# State prediction recall: 1; precision: 1
# error: 0.16241
# State prediction recall: 1; precision: 1
# error: 0.355655
# --- repeat 2 of 3 ---
# -- model: ESN --
# error: 0.464461
# error: 0.478578
# error: 0.431009
# error: 0.416991
# error: 0.466101
# error: 0.483744
# error: 0.431871
# error: 0.459362
# error: 0.441905
# error: 0.422275
# error: 0.441092
# error: 0.474702
# error: 0.480564
# error: 0.420582
# error: 0.439213
# error: 0.427122
# error: 0.466092
# error: 0.436587
# error: 0.456807
# error: 0.481681
# -- model: CRJ --
# error: 0.492421
# error: 0.468742
# error: 0.454263
# error: 0.467675
# error: 0.467068
# error: 0.487812
# error: 0.445729
# error: 0.4887
# error: 0.499389
# error: 0.51118
# error: 0.454262
# error: 0.481364
# error: 0.456122
# error: 0.510215
# error: 0.463598
# error: 0.468989
# error: 0.47618
# error: 0.464107
# error: 0.490171
# error: 0.479149
# -- model: LMU --
# error: 0.448192
# error: 0.445658
# error: 0.449345
# error: 0.445658
# error: 0.449345
# error: 0.448192
# error: 0.448192
# error: 0.445658
# error: 0.449345
# error: 0.449345
# error: 0.448192
# error: 0.445658
# error: 0.448192
# error: 0.449345
# error: 0.445658
# error: 0.449345
# error: 0.448192
# error: 0.445658
# error: 0.448192
# error: 0.449345
# -- model: RMM_ESN --
# State prediction recall: 1; precision: 1
# error: 0.46766
# State prediction recall: 0.894348; precision: 0.894348
# error: 0.469897
# State prediction recall: 1; precision: 1
# error: 0.44912
# State prediction recall: 0.937929; precision: 0.937929
# error: 0.45923
# State prediction recall: 1; precision: 1
# error: 0.500882
# State prediction recall: 1; precision: 1
# error: 0.402792
# State prediction recall: 1; precision: 1
# error: 0.452362
# State prediction recall: 0.992604; precision: 0.992604
# error: 0.471278
# State prediction recall: 1; precision: 1
# error: 0.47069
# State prediction recall: 1; precision: 1
# error: 0.467309
# State prediction recall: 0.909403; precision: 0.909403
# error: 0.469548
# State prediction recall: 1; precision: 1
# error: 0.37991
# State prediction recall: 1; precision: 1
# error: 0.421492
# State prediction recall: 1; precision: 1
# error: 0.47541
# State prediction recall: 0.995246; precision: 0.995246
# error: 0.423599
# State prediction recall: 1; precision: 1
# error: 0.429505
# State prediction recall: 0.983096; precision: 0.983096
# error: 0.425713
# State prediction recall: 1; precision: 1
# error: 0.48182
# State prediction recall: 0.885103; precision: 0.885103
# error: 0.460889
# State prediction recall: 1; precision: 1
# error: 0.474928
# -- model: RMM_CRJ --
# State prediction recall: 0.788695; precision: 0.788695
# error: 0.429003
# State prediction recall: 0.862916; precision: 0.862916
# error: 0.894673
# State prediction recall: 1; precision: 1
# error: 3.76136
# State prediction recall: 1; precision: 1
# error: 0.684757
# State prediction recall: 0.753038; precision: 0.753038
# error: 0.524454
# State prediction recall: 0.862124; precision: 0.862124
# error: 1.82994
# ...
# error: 39.7829
# State prediction recall: 0.973333; precision: 0.980597
# error: 39.7832
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427215
# State prediction recall: 1; precision: 1
# error: 0.427214
# State prediction recall: 1; precision: 1
# error: 0.427141
# State prediction recall: 1; precision: 1
# error: 0.427215
# --- repeat 2 of 3 ---
# -- model: ESN --
# error: 14.8307
# error: 15.0495
# error: 15.2026
# error: 15.5328
# error: 15.2284
# error: 14.7114
# error: 14.7049
# error: 15.3688
# error: 15.842
# error: 15.0183
# error: 15.3305
# error: 14.8712
# error: 15.0534
# error: 15.8359
# error: 14.9989
# error: 14.8513
# error: 14.8375
# error: 15.0617
# error: 14.8918
# error: 14.4763
# -- model: CRJ --
# error: 15.2138
# error: 18.1801
# error: 14.1828
# error: 16.0467
# error: 16.2487
# error: 14.0282
# error: 14.457
# error: 13.9646
# error: 14.9362
# error: 14.2349
# error: 15.0045
# error: 15.2054
# error: 14.7353
# error: 13.5517
# error: 17.848
# error: 14.2394
# error: 14.9672
# error: 15.1935
# error: 14.852
# error: 15.0356
# -- model: LMU --
# error: 58.6617
# error: 58.6617
# error: 58.6616
# error: 58.6616
# error: 58.6617
# error: 58.6617
# error: 58.6617
# error: 58.6617
# error: 58.6616
# error: 58.6617
# error: 58.6616
# error: 58.6617
# error: 58.6616
# error: 58.6617
# error: 58.6617
# error: 58.6616
# error: 58.6617
# error: 58.6617
# error: 58.6617
# error: 58.6616
# -- model: RMM_ESN --
# State prediction recall: 0.983704; precision: 0.988095
# error: 15.4238
# State prediction recall: 0.979259; precision: 0.97349
# error: 15.1013
# State prediction recall: 0.974815; precision: 0.987988
# error: 15.679
# State prediction recall: 0.954074; precision: 0.951256
# error: 15.3644
# State prediction recall: 0.954074; precision: 0.945668
# error: 14.9384
# State prediction recall: 0.954074; precision: 0.936047
# error: 15.4812
# State prediction recall: 0.982222; precision: 0.979321
# error: 15.7889
# State prediction recall: 0.979259; precision: 0.991004
# error: 14.8445
# State prediction recall: 0.979259; precision: 0.979259
# error: 15.4413
# State prediction recall: 0.968889; precision: 0.98051
# error: 15.4694
# State prediction recall: 0.983704; precision: 0.988095
# error: 15.2178
# State prediction recall: 0.980741; precision: 0.976401
# error: 15.544
# State prediction recall: 0.983704; precision: 0.991045
# error: 15.1866
# State prediction recall: 0.977778; precision: 0.990991
# error: 15.1999
# State prediction recall: 0.955556; precision: 0.955556
# error: 15.2299
# State prediction recall: 0.940741; precision: 0.946349
# error: 16.4653
# State prediction recall: 0.96; precision: 0.95858
# error: 15.6169
# State prediction recall: 0.964444; precision: 0.96875
# error: 15.3886
# State prediction recall: 0.985185; precision: 0.985185
# error: 15.8497
# State prediction recall: 0.962963; precision: 0.965825
# error: 16.1895
# -- model: RMM_CRJ --
# State prediction recall: 0.958519; precision: 0.961367
# error: 18.1149
# State prediction recall: 0.971852; precision: 0.982036
# error: 14.6787
# State prediction recall: 0.967407; precision: 0.971726
# error: 14.6519
# State prediction recall: 0.974815; precision: 1
# error: 27.6779
# State prediction recall: 0.988148; precision: 0.983776
# error: 14.4528
# State prediction recall: 0.98963; precision: 0.998505
# error: 13.8988
# State prediction recall: 0.958519; precision: 0.974398
# error: 14.3305
# State prediction recall: 0.971852; precision: 0.980568
# error: 15.6241
# State prediction recall: 0.991111; precision: 0.985272
# error: 14.5396
# State prediction recall: 0.986667; precision: 0.989599
# error: 14.646
# State prediction recall: 0.958519; precision: 0.974398
# error: 14.3306
# State prediction recall: 0.98963; precision: 0.976608
# error: 17.3044
# State prediction recall: 0.961481; precision: 0.986322
# error: 14.8627
# State prediction recall: 0.976296; precision: 0.983582
# error: 15.3483
# State prediction recall: 0.992593; precision: 0.994065
# error: 13.7558
# State prediction recall: 0.96; precision: 0.981818
# error: 22.5738
# State prediction recall: 0.979259; precision: 0.980712
# error: 14.267
# State prediction recall: 0.988148; precision: 0.983776
# error: 14.4528
# State prediction recall: 0.97037; precision: 0.995441
# error: 14.6863
# State prediction recall: 0.958519; precision: 0.975867
# error: 14.8011
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329161
# State prediction recall: 1; precision: 1
# error: 0.329158
# State prediction recall: 1; precision: 1
# error: 0.328904
# State prediction recall: 1; precision: 1
# error: 0.329161
# --- repeat 3 of 3 ---
# -- model: ESN --
# error: 1.90071
# error: 1.90056
# error: 1.90462
# error: 1.90155
# error: 1.90151
# error: 1.90342
# error: 1.90147
# error: 1.9015
# error: 1.89872
# error: 1.90068
# error: 1.90168
# error: 1.90225
# error: 1.90097
# error: 1.90123
# error: 1.90314
# error: 1.90084
# error: 1.90377
# error: 1.90302
# error: 1.90259
# error: 1.90169
# -- model: CRJ --
# error: 1.90221
# error: 1.88032
# error: 1.89671
# error: 1.89812
# error: 1.90014
# error: 1.89984
# error: 1.89582
# error: 1.89644
# error: 1.89708
# error: 1.89445
# error: 1.90239
# error: 1.89748
# error: 1.89635
# error: 1.8941
# error: 1.90763
# error: 1.89615
# error: 1.9026
# error: 1.8936
# error: 1.89957
# error: 1.90127
# -- model: LMU --
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# error: 1.69721
# -- model: RMM_ESN --
# State prediction recall: 0.968889; precision: 0.974665
# error: 1.90048
# State prediction recall: 0.971852; precision: 0.986466
# error: 1.89978
# State prediction recall: 0.964444; precision: 0.976012
# error: 1.90125
# State prediction recall: 0.976296; precision: 0.971976
# error: 1.90088
# State prediction recall: 0.973333; precision: 0.970458
# error: 1.90212
# State prediction recall: 0.988148; precision: 0.976574
# error: 1.90053
# State prediction recall: 0.974815; precision: 0.959184
# error: 1.90185
# State prediction recall: 0.971852; precision: 0.971852
# error: 1.90203
# State prediction recall: 0.962963; precision: 0.980392
# error: 1.90148
# State prediction recall: 0.97037; precision: 0.989426
# error: 1.90094
# State prediction recall: 0.973333; precision: 0.979136
# error: 1.90002
# State prediction recall: 0.983704; precision: 0.983704
# error: 1.90105
# State prediction recall: 0.94963; precision: 0.951039
# error: 1.90079
# State prediction recall: 0.992593; precision: 0.991124
# error: 1.90158
# State prediction recall: 0.982222; precision: 0.996992
# error: 1.89977
# State prediction recall: 0.982222; precision: 0.982222
# error: 1.90199
# State prediction recall: 0.951111; precision: 0.953938
# error: 1.90067
# State prediction recall: 0.961481; precision: 0.962908
# error: 1.90297
# State prediction recall: 0.973333; precision: 0.957726
# error: 1.90276
# State prediction recall: 0.973333; precision: 0.970458
# error: 1.90153
# -- model: RMM_CRJ --
# State prediction recall: 0.964444; precision: 0.96875
# error: 1.90241
# State prediction recall: 0.968889; precision: 0.966027
# error: 1.90402
# State prediction recall: 0.955556; precision: 0.962687
# error: 1.9006
# State prediction recall: 0.976296; precision: 1
# error: 1.94939
# State prediction recall: 0.995556; precision: 0.992614
# error: 1.8959
# State prediction recall: 0.971852; precision: 0.977645
# error: 1.89545
# State prediction recall: 0.968889; precision: 0.974665
# error: 1.89694
# State prediction recall: 0.982222; precision: 0.985141
# error: 1.90299
# State prediction recall: 0.995556; precision: 0.994083
# error: 1.89653
# State prediction recall: 0.985185; precision: 0.992537
# error: 1.90386
# State prediction recall: 0.968889; precision: 0.974665
# error: 1.89694
# State prediction recall: 0.994074; precision: 0.989676
# error: 1.89801
# State prediction recall: 0.97037; precision: 0.992424
# error: 1.89791
# State prediction recall: 0.980741; precision: 0.985119
# error: 1.89978
# State prediction recall: 0.998519; precision: 0.997041
# error: 1.89387
# State prediction recall: 0.974815; precision: 0.992459
# error: 1.8791
# State prediction recall: 0.983704; precision: 0.988095
# error: 1.90058
# State prediction recall: 0.995556; precision: 0.992614
# error: 1.8959
# State prediction recall: 0.982222; precision: 0.991031
# error: 1.90277
# State prediction recall: 0.968889; precision: 0.981982
# error: 1.89707
# -- model: RMM_LMU --
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358219
# State prediction recall: 1; precision: 1
# error: 0.0358205
# State prediction recall: 1; precision: 1
# error: 0.0358219
#
# Selected the following hyper-parameters for ESN
# radius: 0.5
# sparsity: 0.2
# regul: 0.001
# errors: [39.777322169874466, 14.476330165021707, 1.901694883524274]
#
# Selected the following hyper-parameters for CRJ
# v: 0.3
# w_c: 0.1
# w_j: 0.1
# l: 16
# regul: 0.001
# errors: [39.77752950633665, 13.551712095135494, 1.894100287613039]
#
# Selected the following hyper-parameters for LMU
# regul: 0.001
# errors: [6.531305396809781, 58.66161104169124, 1.6972085228134153]
# T: 312
#
# Selected the following hyper-parameters for RMM_ESN
# radius: 0.9
# sparsity: 0.2
# regul: 0.001
# C: 1.0
# svm_kernel: pseudo
# errors: [39.782679925837364, 14.844510072539236, 1.9020327228377043]
#
# Selected the following hyper-parameters for RMM_CRJ
# v: 0.1
# w_c: 0.1
# w_j: 0.2
# l: 4
# regul: 1e-05
# C: 10000.0
# svm_kernel: pseudo
# errors: [39.779248653369784, 13.755771308585443, 1.8938744690778349]
#
# Selected the following hyper-parameters for RMM_LMU
# regul: 0.001
# C: 1.0
# svm_kernel: pseudo
# errors: [0.4271408976373649, 0.328904437294851, 0.03582050546595066]
# T: 312
# --- repeat 1 of 20 ---
# State prediction recall: 0.965926; precision: 0.968796
# State prediction recall: 0.995556; precision: 0.994083
# State prediction recall: 1; precision: 1
# --- repeat 2 of 20 ---
# State prediction recall: 0.983704; precision: 0.973607
# State prediction recall: 0.998519; precision: 0.998519
# State prediction recall: 0.998519; precision: 0.998519
# --- repeat 3 of 20 ---
# State prediction recall: 0.986667; precision: 0.980854
# State prediction recall: 0.998519; precision: 0.998519
# State prediction recall: 1; precision: 1
# --- repeat 4 of 20 ---
# State prediction recall: 0.951111; precision: 0.945508
# State prediction recall: 0.998519; precision: 0.998519
# State prediction recall: 1; precision: 1
# --- repeat 5 of 20 ---
# State prediction recall: 0.985185; precision: 0.977941
# State prediction recall: 0.992593; precision: 0.992593
# State prediction recall: 1; precision: 1
# --- repeat 6 of 20 ---
# State prediction recall: 0.971852; precision: 0.986466
# State prediction recall: 0.995556; precision: 0.997033
# State prediction recall: 1; precision: 1
# --- repeat 7 of 20 ---
# State prediction recall: 0.973333; precision: 0.969027
# State prediction recall: 0.997037; precision: 0.995562
# State prediction recall: 1; precision: 1
# --- repeat 8 of 20 ---
# State prediction recall: 0.982222; precision: 0.980769
# State prediction recall: 0.998519; precision: 0.998519
# State prediction recall: 1; precision: 1
# --- repeat 9 of 20 ---
# State prediction recall: 0.986667; precision: 0.988131
# State prediction recall: 0.527407; precision: 0.526627
# State prediction recall: 1; precision: 1
# --- repeat 10 of 20 ---
# State prediction recall: 0.985185; precision: 0.983728
# State prediction recall: 0.994074; precision: 0.994074
# State prediction recall: 1; precision: 1
# --- repeat 11 of 20 ---
# State prediction recall: 0.971852; precision: 0.961877
# State prediction recall: 0.986667; precision: 0.986667
# State prediction recall: 1; precision: 1
# --- repeat 12 of 20 ---
# State prediction recall: 0.933333; precision: 0.969231
# State prediction recall: 0.98963; precision: 0.98963
# State prediction recall: 1; precision: 1
# --- repeat 13 of 20 ---
# State prediction recall: 0.948148; precision: 0.980092
# State prediction recall: 0.998519; precision: 0.997041
# State prediction recall: 1; precision: 1
# --- repeat 14 of 20 ---
# State prediction recall: 0.977778; precision: 0.979228
# State prediction recall: 0.992593; precision: 0.994065
# State prediction recall: 1; precision: 1
# --- repeat 15 of 20 ---
# State prediction recall: 0.983704; precision: 0.989568
# State prediction recall: 0.998519; precision: 0.998519
# State prediction recall: 1; precision: 1
# --- repeat 16 of 20 ---
# State prediction recall: 0.977778; precision: 0.969163
# State prediction recall: 0.997037; precision: 0.995562
# State prediction recall: 1; precision: 1
# --- repeat 17 of 20 ---
# State prediction recall: 0.952593; precision: 0.9442
# State prediction recall: 0.548148; precision: 0.548148
# State prediction recall: 1; precision: 1
# --- repeat 18 of 20 ---
# State prediction recall: 0.986667; precision: 0.982301
# State prediction recall: 0.991111; precision: 0.989645
# State prediction recall: 1; precision: 1
# --- repeat 19 of 20 ---
# State prediction recall: 0.985185; precision: 0.979381
# State prediction recall: 0.994074; precision: 0.997028
# State prediction recall: 1; precision: 1
# --- repeat 20 of 20 ---
# State prediction recall: 0.939259; precision: 0.940653
# State prediction recall: 0.997037; precision: 0.995562
# State prediction recall: 1; precision: 1
# ESN: 12.2112 +- 22.7266 (took 1.91341 seconds)
# CRJ: 12.0666 +- 22.7565 (took 1.76516 seconds)
# LMU: 11.056 +- 19.69 (took 1.98102 seconds)
# RMM_ESN: 12.2126 +- 22.7222 (took 2.96306 seconds)
# RMM_CRJ: 12.0544 +- 22.7592 (took 2.72585 seconds)
# RMM_LMU: 4.79384 +- 20.2052 (took 2.93036 seconds)
